# %%
from dotenv import load_dotenv
from elasticsearch import Elasticsearch
import requests, os
import pandas as pd

# %%
# You need to add the infos in the .env file
load_dotenv()

ES_HOST = os.getenv("ES_HOST")
ES_PASSWORD = os.getenv("ES_PASSWORD")
ES_USER = os.getenv("ES_USER")
es = Elasticsearch(ES_HOST, http_auth=(ES_USER, ES_PASSWORD))
INDEX_PROJECTS = f'scanr-projects'
INDEX_ORGANIZATIONS = f'scanr-organizations'

# %% [markdown]
# # 1. First get the id of the instutions

# %%
user_query = 'le mans université'

# %%
payload = {
    'size': 10,
    '_source': # the fields we want to get 
    ['id', 'label.*', 'status', 'level'],
 'sort': [{'_score': {'order': 'desc'}}, {'id.keyword': {'order': 'desc'}}],
 'query': {'bool': {'must': [
     {'query_string': {'query': user_query}},
     {'terms': {'status.keyword': ['active']}},
 ]
                   }}}
                    
res = es.search(index=INDEX_ORGANIZATIONS, request_cache=False, request_timeout=6000, body=payload)
pd.DataFrame(e['_source'] for e in res['hits']['hits'])
# Out:
#            id  status                                              label  \
# 0       9xlel  active                       {'fr': 'Le Mans Université'}
# 1  200815562K  active  {'fr': 'Themis université du Mans', 'default':...
# 2   576450431  active                       {'default': 'GRUAU LE MANS'}
# 3  202023718Y  active  {'fr': 'Atelier de Recherche en Gestion de l'U...
# 4   480449388  active                {'default': 'LE MANS PROCESS AGRO'}
# 5  200615275G  active  {'fr': 'Laboratoire d'informatique de l'univer...
# 6  199612385J  active  {'fr': 'Laboratoire d'acoustique de l'universi...
# 7  202123746Z  active  {'fr': 'Centre de recherche Humanités et Socié...
# 8   247200132  active  {'default': 'LE MANS METROPOLE COMMUNAUTE URBA...
# 9  200810693T  active  {'fr': 'Fédération de recherche mathématiques ...
#
#                   level
# 0                 EPSCP
# 1    Unité de recherche
# 2                   NaN
# 3    Unité de recherche
# 4                   NaN
# 5    Unité de recherche
# 6    Unité de recherche
# 7    Unité de recherche
# 8                   NaN
# 9  Structure fédérative

# %%
## From the list above, find the right organizations

# %%
institution_id = '9xlel'

# %% [markdown]
# # 2. Get the grants linked to that institution_id
# ## Either directly in the list of participants (participants.structure.id), or in their supervisors

# %%
payload = {
    'size': 10000,
    '_source': # the fields we want to get 
    ['label.*', 'acronym.*',
  'project_domains',
  'participants.label',
  'participants.structure.id',
  'participants.structure.label.*',
  'participants.structure.mainAddress.*',
  'year',
  'type',
  'id',
  'keywords.*'],
 'sort': [{'_score': {'order': 'desc'}}, {'id.keyword': {'order': 'desc'}}],
 'highlight': {'number_of_fragments': 3,
  'fragment_size': 125,
  'pre_tags': ['<strong>'],
  'post_tags': ['</strong>'],
  'fields': {'label.default': {},
   'description.default': {},
   'domains.label.default': {}}},
 'query': {'bool': {
     'should': [
     {'terms': {'participants.structure.id.keyword': [institution_id]}},
     {'terms': {'participants.structure.institutions.structure.keyword': [institution_id]}},
 
 ],
  "minimum_should_match": 1
   }
          }}

# %%
res = es.search(index=INDEX_PROJECTS, request_cache=False, request_timeout=6000, body=payload)

# %%
data = [e['_source'] for e in res['hits']['hits']]

# %%
df_results = pd.DataFrame(data)

# %%
len(df_results)
# Out:
# 285

# %%
df_results.type.value_counts()
# Out:
# ANR                  223
# PIA ANR               22
# Horizon Europe        16
# Horizon 2020          13
# DIM Ile-de-France      6
# i-LAB                  4
# ANSES                  1
# Name: type, dtype: int64

# %%
pd.DataFrame(e['_source'] for e in res['hits']['hits'])
# Out:
#                type  year         id                      acronym  \
# 0    Horizon Europe  2023  101168870           {'default': 'ESM'}
# 1    Horizon Europe  2023  101148965  {'default': 'PRIMONPLANTS'}
# 2    Horizon Europe  2022  101119903         {'default': 'VAMOR'}
# 3    Horizon Europe  2022  101094949         {'default': 'NEXUS'}
# 4    Horizon Europe  2022  101081357       {'default': 'REWRITE'}
# ..              ...   ...        ...                          ...
# 280    Horizon 2020  2020  101036048       {'default': 'VOYAGES'}
# 281    Horizon 2020  2020  101025424         {'default': 'STSAW'}
# 282    Horizon 2020  2020  101007851  {'default': 'DISCO2 STORE'}
# 283    Horizon 2020  2020  101007666     {'default': 'ESPERANTO'}
# 284    Horizon 2020  2020  101007579     {'default': 'SciCoMove'}
#
#                                                  label  \
# 0                    {'default': 'Edible Soft Matter'}
# 1    {'default': 'PeeRing into the mechanIsm of syn...
# 2    {'default': 'Vibro-Acoustic Model Order Reduct...
# 3    {'default': 'Twinning Research and Innovation ...
# 4    {'default': 'REWilding and Restoration of Inte...
# ..                                                 ...
# 280                             {'default': 'Voyages'}
# 281      {'default': 'Sub-THz Surface Acoustic Waves'}
# 282  {'default': 'Discontinuities in CO2 Storage Re...
# 283  {'default': 'Exchanges for SPEech ReseArch aNd...
# 284  {'default': 'Scientific Collections on the Mov...
#
#                                           participants  \
# 0    [{'label': {'default': 'Le Mans Université__-_...
# 1    [{'label': {'default': 'University of Namur__-...
# 2    [{'label': {'default': 'Tyrens sverige ab__-__...
# 3    [{'label': {'default': 'Bay Zoltán Foundation ...
# 4    [{'label': {'default': 'Le Mans Université__-_...
# ..                                                 ...
# 280  [{'label': {'default': 'Université Marie et Lo...
# 281  [{'label': {'default': 'Le Mans Université__-_...
# 282  [{'label': {'default': 'Le Mans Université__-_...
# 283  [{'label': {'default': 'Université Grenoble Al...
# 284  [{'label': {'default': 'University of Bonn__-_...
#
#                                               keywords  \
# 0    {'en': ['food sciences', 'food structure', 'ed...
# 1    {'en': ['bioengineering', 'foaming', 'plants',...
# 2    {'en': ['model order reduction', 'vibration an...
# 3    {'en': ['inclusiveness', 'gender equality plan...
# 4    {'en': ['intertidal seascapes', 'soft sediment...
# ..                                                 ...
# 280  {'en': ['researchers', 'publics', 'meetings', ...
# 281  {'en': ['surface acoustic waves', 'picosecond ...
# 282  {'en': ['co2 storage', 'mechanical discontinui...
# 283  {'en': ['speech processing', 'neural networks'...
# 284  {'en': ['museums', 'collections', 'history of ...
#
#                                        project_domains
# 0    [{'label': {'default': 'food sciences'}, 'code...
# 1    [{'label': {'default': 'foaming'}, 'code': 'Q2...
# 2    [{'label': {'default': 'model order reduction'...
# 3    [{'label': {'default': 'inclusiveness'}, 'code...
# 4    [{'label': {'default': 'intertidal'}, 'code': ...
# ..                                                 ...
# 280  [{'label': {'default': 'voyage'}, 'code': 'Q18...
# 281  [{'label': {'default': 'acoustic waves'}, 'cod...
# 282  [{'label': {'default': 'discontinuities'}, 'co...
# 283  [{'label': {'default': 'speech processing'}, '...
# 284  [{'label': {'default': 'museums'}, 'code': 'Q3...
#
# [285 rows x 8 columns]
